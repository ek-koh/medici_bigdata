# %% [markdown]
# # 앤스콤 데이터 집합 불러오기

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset("anscombe")

# %%
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
print(type(anscombe))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # matplotlib 라이브러리로 간단한 그래프 그리기

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 'o')

# %% [markdown]
# # 한 번에 4개의 그래프 그리기

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']

# %%
dataset_3 = anscombe[anscombe['dataset'] == 'III']

# %%
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %% [markdown]
# #### 그래프 격자가 위치할 기본 틀 만들기

# %%
fig = plt.figure()

# %% [markdown]
# #### 그래프 격자 그리기: add_subplot 메서드

# %%
axes1 = fig.add_subplot(2, 2, 1)

# %%
axes2 = fig.add_subplot(2, 2, 2)

# %%
axes3 = fig.add_subplot(2, 2, 3)

# %%
axes4 = fig.add_subplot(2, 2, 4)

# %% [markdown]
# #### plot 메서드에 데이터 전달하여 그래프 그리기

# %%
axes1.plot(dataset_1['x'], dataset_1['y'], 'o')

# %%
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')

# %%
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')

# %%
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

# %% [markdown]
# #### 그래프 확인하기

# %%
fig

# %% [markdown]
# #### 그래프 격자에 제목 추가

# %%
axes1.set_title("dataset_1")
# Out:
# Text(0.5, 1, 'dataset_1')

# %%
axes2.set_title("dataset_2")
# Out:
# Text(0.5, 1, 'dataset_2')

# %%
axes3.set_title("dataset_3")
# Out:
# Text(0.5, 1, 'dataset_3')

# %%
axes4.set_title("dataset_4")
# Out:
# Text(0.5, 1, 'dataset_4')

# %%
fig

# %% [markdown]
# #### 기본 틀(fig)에 제목 추가

# %%
fig.suptitle("Anscombe Data")
# Out:
# Text(0.5, 0.98, 'Anscombe Data')

# %%
fig

# %% [markdown]
# #### 그래프간 거리 띄우기

# %%
fig.tight_layout()

# %%
fig

# %% [markdown]
# # 기초 그래프 그리기 - 히스토그램, 산점도, 박스 그래프

# %%
tips = sns.load_dataset("tips")

# %%
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
print(type(tips))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # 단변량 그래프 그리기 - 히스토그램

# %%
tips.hist('total_bill')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001DBC56C3B88>]],
#       dtype=object)

# %%
fig = plt.figure()

# %%
axes1 = fig.add_subplot(1, 1, 1)

# %%
axes1.hist(tips['total_bill'], bins = 10)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <a list of 10 Patch objects>)

# %%
axes1.set_title('Histogram of Total Bill')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Bill')

# %%
axes1.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
axes1.set_xlabel('Total Bill')
# Out:
# Text(0.5, 0, 'Total Bill')

# %%
fig

# %%
tips['total_bill'].describe()
# Out:
# count    244.000000
# mean      19.785943
# std        8.902412
# min        3.070000
# 25%       13.347500
# 50%       17.795000
# 75%       24.127500
# max       50.810000
# Name: total_bill, dtype: float64

# %% [markdown]
# # 이변량 그래프 그리기 - 산점도, 박스 그래프

# %% [markdown]
# #### 산점도

# %%
scatter_plot = plt.figure()

# %%
axes1 = scatter_plot.add_subplot(1, 1, 1)

# %%
axes1.plot(tips['total_bill'], tips['tip'],'o')

# %%
scatter_plot

# %%
axes1 = scatter_plot.add_subplot(1, 1, 1)
# Out:
# C:\Users\B0113\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   """Entry point for launching an IPython kernel.

# %%
axes1.scatter(tips['total_bill'], tips['tip'])

# %%
axes1.set_title('Scatterplot of Total Bill vs. Tip')
# Out:
# Text(0.5, 1, 'Scatterplot of Total Bill vs. Tip')

# %%
axes1.set_xlabel('Total Bill')
# Out:
# Text(0.5, 3.1999999999999993, 'Total Bill')

# %%
axes1.set_ylabel('Tip')
# Out:
# Text(3.200000000000003, 0.5, 'Tip')

# %%
scatter_plot

# %% [markdown]
# #### 박스플랏

# %%
boxplot = plt.figure()

# %%
axes1 = boxplot.add_subplot(1, 1, 1)

# %%
axes1.boxplot(
    [tips[tips['sex'] == 'Female']['tip'],
    tips[tips['sex'] == 'Male']['tip']],
    labels = ['Femail', 'Male'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1dbc58a2408>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1dbc58583c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1dbc589dc08>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1dbc58746c8>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1dbc5858b88>,
# ...
#  'means': []}

# %%
axes1.set_xlabel('Sex')
# Out:
# Text(0.5, 0, 'Sex')

# %%
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
boxplot

# %% [markdown]
# # 다변량 그래프 그리기

# %% [markdown]
# 산점도 그래프 - 지불금액(total_bill), 팁(tip), 성별(sex)

# %% [markdown]
# #### 성별의 각 문자열을 정수로 치환하는 함수 만들기

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %% [markdown]
# #### recode_sex 메서드가 반환한 값을 데이터프레임에 추가

# %%
tips['sex_color'] = tips['sex'].apply(recode_sex)

# %% [markdown]
# #### 그래프 그리기

# %%
scatter_plot = plt.figure()

# %%
axes1 = scatter_plot.add_subplot(1, 1, 1)

# %%
axes1.scatter(
    x=tips['total_bill'],
    y=tips['tip'],
    s=tips['size']*10,
    c=tips['sex_color'],
    alpha = 0.5
)

axes1.set_title('Total Bill vs. Tip Colored by Sex and Sized by Size')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
scatter_plot

# %% [markdown]
# # seaborn 라이브러리 활용하기

# %% [markdown]
# ## 단변량그래프

# %%
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %% [markdown]
# #### distplot

# %%
ax = plt.subplots()

ax = sns.distplot(tips['total_bill'])

ax.set_title('Total Bill Histogram with Density Plot')
# Out:
# Text(0.5, 1.0, 'Total Bill Histogram with Density Plot')

# %% [markdown]
# #### 히스토그램만 나타내기

# %%
ax = plt.subplots()

ax = sns.distplot(tips['total_bill'], kde=False)

ax.set_title('Total Bill Histogram')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### 밀집도 그래프만 나타내기

# %%
ax = plt.subplots()

ax = sns.distplot(tips['total_bill'], hist=False)

ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### 히스토그램 + 밀집도 + 양탄자 그래프

# %%
ax = plt.subplots()
ax = sns.distplot(tips['total_bill'], rug=True)
ax.set_title('Total Bill Histogram with Density and Rug Plot')
ax.set_xlabel('Total Bill')
# Out:
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# #### count 그래프로 요일 나타내기

# %%
ax = plt.subplots()
ax = sns.countplot('day', data = tips)
ax.set_title('Count of Days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ## 이변량 그래프

# %% [markdown]
# #### 산점도

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data = tips)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### 회귀선 없는 산점도

# %%
ax = plt.subplots()
ax = sns.regplot(x='total_bill', y='tip', data = tips,fit_reg = False)
ax.set_title('Scatterplot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### 산점도와 히스토그램 한번에 나타내는 jointplot

# %%
joint = sns.jointplot(x='total_bill', y='tip', data = tips)
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
joint.fig.suptitle('Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### jointplot의 kind 인잣값을 설정하여 육각그래프 나타내기

# %%
hexbin = sns.jointplot(x='total_bill', y='tip', data = tips, kind='hex')
hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.fig.suptitle('Hexbin Joint Plot of Total Bill and Tip', fontsize=10, y=1.03)
# Out:
# Text(0.5, 1.03, 'Hexbin Joint Plot of Total Bill and Tip')

# %% [markdown]
# #### 이차원 밀집도 그래프

# %%
ax = sns.kdeplot(data=tips['total_bill'], data2=tips['tip'], shade=True)
ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %% [markdown]
# #### 바 그래프

# %%
ax = sns.barplot(x='time', y='total_bill', data=tips)
ax.set_title('Bar Plot of Average Total Bill for Time of the Day')
ax.set_xlabel('Time of the Day')
ax.set_ylabel('Average Total Bill')
# Out:
# Text(0, 0.5, 'Average Total Bill')

# %% [markdown]
# #### 박스그래프

# %%
ax = sns.boxplot(x='time', y='total_bill', data=tips)
ax.set_title('Boxplot of Total Bill by Time of the Day')
ax.set_xlabel('Time of the Day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### 바이올린 그래프

# %%
ax = sns.violinplot(x='time', y='total_bill', data=tips)
ax.set_title('Violinplot of Total Bill by Time of the Day')
ax.set_xlabel('Time of the Day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# #### 관계 그래프 그리기

# %%
fig = sns.pairplot(tips)

# %%
pair_grid = sns.PairGrid(tips)
pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.distplot, rug = True)
plt.show()

# %% [markdown]
# ## 다변량 그래프

# %% [markdown]
# #### 바이올린 그래프

# %%
ax = sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)

# %% [markdown]
# #### 산점도

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', fit_reg=False)

# %% [markdown]
# #### 관계 그래프

# %%
fig = sns.pairplot(tips, hue='sex')

# %% [markdown]
# #### 산점도 그래프의 크기와 모양 조절하기

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex',
                    scatter_kws={'s': tips['size'] * 30, 'alpha': 0.5})

# %%
scatter = sns.lmplot(x='total_bill', y='tip', data=tips, fit_reg=False, hue='sex', markers=['o','x'],
                    scatter_kws={'s': tips['size'] * 10})

# %% [markdown]
# #### lmplot 메서드로 4개의 데이터 그룹에 대한 그래프 한 번에 그리기

# %%
anscombe_plot = sns.lmplot('x','y', data = anscombe, fit_reg=False)

# %%
anscombe_plot = sns.lmplot('x','y', data= anscombe, fit_reg=False, col = 'dataset', col_wrap=2)

# %% [markdown]
# ## 알아두면 좋아요

# %% [markdown]
# ### FacetGrid 클래스로 그룹별 그래프 그리기

# %%
facet = sns.FacetGrid(tips, col='time')
facet.map(sns.distplot, 'total_bill', rug=True)

# %%
facet = sns.FacetGrid(tips, col='day', hue='sex', col_wrap=2)
facet = facet.map(plt.scatter, 'total_bill', 'tip')
facet = facet.add_legend()

# %% [markdown]
# # 데이터프레임과 시리즈로 그래프 그리기

# %% [markdown]
# #### 히스토그램

# %%
ax = tips['total_bill'].plot.hist(bins=20, alpha = 0.7)
ax.set_xlabel('Total Bill')
# Out:
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# #### 2개의 시리즈로 히스토그램 그리기

# %%
fig, ax = plt.subplots()
ax = tips[['total_bill', 'tip']].plot.hist(bins=20, alpha=0.5, ax = ax)

# %% [markdown]
# #### 밀집도 그래프

# %%
ax = tips['tip'].plot.kde()

# %% [markdown]
# #### 산점도

# %%
fig, ax = plt.subplots()
tips.plot.scatter('total_bill','tip', ax=ax)

# %%
fig, ax = plt.subplots()
ax = tips.plot.hexbin('total_bill', 'tip', gridsize=30, ax = ax)

# %% [markdown]
# #### 박스그래프

# %%
fig, ax = plt.subplots()
ax = tips.plot.box(ax = ax)

# %% [markdown]
# # seaborn 라이브러리로 그래프 스타일 설정하기

# %%
fig, ax = plt.subplots()
ax = sns.violinplot('time', 'total_bill', hue = 'sex', split=True, data=tips)

# %% [markdown]
# ##### darkgrid, whitegrid, dark, white, ticks

# %%
sns.set_style('darkgrid')
fig, ax = plt.subplots()
ax = sns.violinplot('time', 'total_bill', hue = 'sex', split=True, data=tips)

# %%
fig = plt.figure()

seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']

for idk, style in enumerate(seaborn_styles):
    plot_position = idk + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot('time', 'total_bill', data=tips, ax = ax)
        violin.set_title(style)
        
fig.tight_layout()
